# %% [markdown]
# Data Source: https://en.wikipedia.org/wiki/List_of_highest_funded_crowdfunding_projects
#
# Table Tool for Extraction:
# https://wikitable2csv.ggor.de/

# %%
import pandas as pd

# %%
df1 = pd.read_csv('./table-1.csv')
df2 = pd.read_csv('./table-2.csv')
df3 = pd.read_csv('./table-3.csv')

df = pd.concat([df1, df2, df3])

# %%
df
# Out:
#                                  Amount raised        Campaign end date  \
# 0                           $4,000,000,000+[1]             June 1, 2018
# 1                              $257,000,000[4]  September 7, 2017[2][3]
# 2                              $232,000,000[5]            July 14, 2017
# 3                             $204,000,000+[6]                  Ongoing
# 4                             $158,000,000[11]           December, 2017
# 5                             $153,000,000[13]            June 12, 2017
# 6                             $150,000,000[16]         May 28, 2016[15]
# 7                             $144,300,000[18]     October 27, 2017[17]
# 8                             $103,000,000[19]            June 21, 2017
# 9                $102,000,000[citation needed]                  Ongoing
# 10               $80,000,000 (245,832 ETH)[23]            June 24, 2017
# 11                             $70,600,000[25]        December 26, 2017
# ...
